# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
data=pd.read_csv('house_price.csv')

# %%
DF1=pd.DataFrame(data)
DF1
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea Abovemedianprice
# ...

# %%
DF1.head(5)
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea Abovemedianprice
# 0             3             8           0       548.0              Yes
# 1             3             6           1       460.0              Yes
# 2             3             6           1         NaN              Yes
# 3             3             7           1         NaN               no
# 4             4             9           1       836.0              Yes

# %%
DF1.tail(5)
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea Abovemedianprice
# 1455             3             7           1       460.0              Yes
# 1456             3             7           2       500.0              Yes
# 1457             4             9           2       252.0              Yes
# 1458             2             5           0       240.0               no
# 1459             3             6           0       276.0               no

# %%
DF1.shape
# Out:
# (1460, 11)

# %%
DF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1454 non-null   float64
#  10  Abovemedianprice  1460 non-null   object
# dtypes: float64(1), int64(9), object(1)
# memory usage: 125.6+ KB

# %%
DF2 = DF1[['LotArea','BedroomAbvGr']].iloc[:100]
DF2
# Out:
#     LotArea  BedroomAbvGr
# 0      8450             3
# 1      9600             3
# 2     11250             3
# 3      9550             3
# 4     14260             4
# ..      ...           ...
# 95     9765             3
# 96    10264             3
# 97    10921             3
# 98    10625             2
# 99     9320             3
#
# [100 rows x 2 columns]

# %%
DF2.to_csv('DF11.csv',index = False)

# %%
DF1['LotArea'].max()
# Out:
# 215245

# %%
DF1['LotArea'].min()
# Out:
# 1300

# %%
DF1[DF1['LotArea']>10650]
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 2       11250            7            5          920         2         1
# 4       14260            8            5         1145         2         1
# 5       14115            5            5          796         1         1
# 10      11200            5            5         1040         1         0
# 11      11924            9            5         1175         3         0
# ...       ...          ...          ...          ...       ...       ...
# 1442    11003           10            5         1017         2         1
# 1446    26142            5            7         1188         1         0
# 1448    11767            4            7          560         1         1
# 1453    17217            5            5         1140         1         0
# 1456    13175            6            6         1542         2         0
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea Abovemedianprice
# ...

# %%
DF1["TotalBsmtSF"].mean()
# Out:
# 1057.4294520547944

# %%
DF1["TotalBsmtSF"].median()
# Out:
# 991.5

# %%
DF1["TotalBsmtSF"].unique()
# Out:
# array([ 856, 1262,  920,  756, 1145,  796, 1686, 1107,  952,  991, 1040,
#        1175,  912, 1494, 1253,  832, 1004,    0, 1114, 1029, 1158,  637,
#        1777, 1060, 1566,  900, 1704, 1484,  520,  649, 1228, 1234, 1398,
#        1561, 1117, 1097, 1297, 1057, 1088, 1350,  840,  938, 1150, 1752,
#        1434, 1656,  736,  955,  794,  816, 1842,  384, 1425,  970,  860,
#        1410,  780,  530, 1370,  576, 1143, 1947, 1453,  747, 1304, 2223,
#         845, 1086,  462,  672, 1768,  440,  896, 1237, 1563, 1065, 1288,
#         684,  612, 1013,  990, 1235,  876, 1214,  824,  680, 1588,  960,
#         458,  950, 1610,  741, 1226, 1053,  641,  789,  793, 1844,  994,
#        1264, 1809, 1028,  729, 1092, 1125, 1673,  728,  732, 1080, 1199,
#        1362, 1078,  660, 1008,  924,  992, 1063, 1267, 1461, 1907,  928,
#         864, 1734,  910, 1490, 1728,  715,  884,  969, 1710,  825, 1602,
#        1200,  572,  774, 1392, 1232, 1572, 1541,  882, 1149,  644, 1617,
# ...

# %%
DF1.sort_values(by=['TotalBsmtSF'],ascending=False)
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 1298    63887           10            5         6110         2         1
# 332     10655            8            5         3206         2         0
# 496     12692            8            5         3200         3         0
# 523     40094           10            5         3138         3         1
# 440     15431           10            5         3094         2         0
# ...       ...          ...          ...          ...       ...       ...
# 1412     7200            4            5            0         2         0
# 1179     8335            5            5            0         1         0
# 102      7018            5            5            0         2         0
# 259     12702            5            5            0         1         0
# 1048    21750            5            4            0         1         0
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea Abovemedianprice
# ...

# %%
DF1.sort_values(by=['TotalBsmtSF'],ascending=True)
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 646      7200            5            5            0         1         0
# 1035    11500            4            3            0         1         0
# 392      8339            5            7            0         1         0
# 749      8405            4            3            0         2         0
# 1011     9825            5            5            0         2         0
# ...       ...          ...          ...          ...       ...       ...
# 440     15431           10            5         3094         2         0
# 523     40094           10            5         3138         3         1
# 496     12692            8            5         3200         3         0
# 332     10655            8            5         3206         2         0
# 1298    63887           10            5         6110         2         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea Abovemedianprice
# ...

# %%
DF1['GarageArea'].isnull()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: GarageArea, Length: 1460, dtype: bool

# %%
mean=DF1['GarageArea'].mean()
mean
# Out:
# 472.61416781292985

# %%
DF1['GarageArea'].fillna(472.61416781292985,inplace=True)
DF1
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea Abovemedianprice
# ...

# %%
DF1['GarageArea'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: GarageArea, Length: 1460, dtype: bool

# %%
DF1['Abovemedianprice'] = DF1['Abovemedianprice'].replace({"Yes": 1, "no": 0})
DF1
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  Abovemedianprice
# ...

# %%
DF1.plot.scatter(x='GarageArea',y='LotArea')
# Out:
# <Axes: xlabel='GarageArea', ylabel='LotArea'>

# %%
from sklearn import preprocessing
min_max_scaler= preprocessing.MinMaxScaler()
col_name= DF1.columns[:]
x =DF1.loc[:,col_name]
x =pd.DataFrame(data= min_max_scaler.fit_transform(x),columns =col_name)
print(DF1.head())
print(x.head())
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  Abovemedianprice
# 0             3             8           0  548.000000                 1
# 1             3             6           1  460.000000                 1
# 2             3             6           1  472.614168                 1
# 3             3             7           1  472.614168                 0
# 4             4             9           1  836.000000                 1
#     LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# ...

# %%
x.to_csv('DF3.csv')

# %%
from sklearn import preprocessing
min_max_scaler= preprocessing.MinMaxScaler(feature_range=(-1,1))
col_name= DF1.columns[:]
x =DF1.loc[:,col_name]
x =pd.DataFrame(data= min_max_scaler.fit_transform(x),columns =col_name)
print(DF1.head())
print(x.head())
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  Abovemedianprice
# 0             3             8           0  548.000000                 1
# 1             3             6           1  460.000000                 1
# 2             3             6           1  472.614168                 1
# 3             3             7           1  472.614168                 0
# 4             4             9           1  836.000000                 1
#     LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# ...

# %%
from sklearn import preprocessing
min_max_scaler= preprocessing.MinMaxScaler(feature_range=(2,3))
col_name= DF1.columns[:]
x =DF1.loc[:,col_name]
x =pd.DataFrame(data= min_max_scaler.fit_transform(x),columns =col_name)
print(DF1.head())
print(x.head())
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  Abovemedianprice
# 0             3             8           0  548.000000                 1
# 1             3             6           1  460.000000                 1
# 2             3             6           1  472.614168                 1
# 3             3             7           1  472.614168                 0
# 4             4             9           1  836.000000                 1
#     LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# ...

# %%
max_value =abs(DF1['LotArea']).max()
j =len(str(int(max_value)))
DF1['LotArea_DecimalScaled'] =DF1['LotArea']/ (10 ** j)
print("Decimal Scaled LotArea:")
print(DF1[['LotArea', 'LotArea_DecimalScaled']])
# Out:
# Decimal Scaled LotArea:
#       LotArea  LotArea_DecimalScaled
# 0        8450               0.008450
# 1        9600               0.009600
# 2       11250               0.011250
# 3        9550               0.009550
# 4       14260               0.014260
# ...       ...                    ...
# 1455     7917               0.007917
# 1456    13175               0.013175
# 1457     9042               0.009042
# 1458     9717               0.009717
# 1459     9937               0.009937
#
# [1460 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
lot_area_scaled= scaler.fit_transform(DF1[['LotArea']])
DF1['LotArea_ZScoreNormalized'] =lot_area_scaled
print("Z-Score NormalizedLotArea:")
print(DF1[['LotArea', 'LotArea_ZScoreNormalized']])
# Out:
# Z-Score NormalizedLotArea:
#       LotArea  LotArea_ZScoreNormalized
# 0        8450                 -0.207142
# 1        9600                 -0.091886
# 2       11250                  0.073480
# 3        9550                 -0.096897
# 4       14260                  0.375148
# ...       ...                       ...
# 1455     7917                 -0.260560
# 1456    13175                  0.266407
# 1457     9042                 -0.147810
# 1458     9717                 -0.080160
# 1459     9937                 -0.058112
#
# [1460 rows x 2 columns]

# %%
from sklearn import preprocessing
min_max_scaler= preprocessing.StandardScaler()
col_name= DF1.columns[:]
x =DF1.loc[:,col_name]
x =pd.DataFrame(data= min_max_scaler.fit_transform(x),columns =col_name)
print(DF1.head())
print(x.head())
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  Abovemedianprice  \
# 0             3             8           0  548.000000                 1
# 1             3             6           1  460.000000                 1
# 2             3             6           1  472.614168                 1
# 3             3             7           1  472.614168                 0
# 4             4             9           1  836.000000                 1
#
#    LotArea_DecimalScaled  LotArea_ZScoreNormalized
# 0                0.00845                 -0.207142
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df =pd.DataFrame(x)
X =df.drop('LotArea',axis=1)
X
# Out:
#       OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  BedroomAbvGr  \
# 0        0.651479    -0.517200    -0.459303  0.789741  1.227585      0.163779
# 1       -0.071836     2.179628     0.466465  0.789741 -0.761621      0.163779
# 2        0.651479    -0.517200    -0.313369  0.789741  1.227585      0.163779
# 3        0.651479    -0.517200    -0.687324 -1.026041 -0.761621      0.163779
# 4        1.374795    -0.517200     0.199680  0.789741  1.227585      1.390023
# ...           ...          ...          ...       ...       ...           ...
# 1455    -0.071836    -0.517200    -0.238122  0.789741  1.227585      0.163779
# 1456    -0.071836     0.381743     1.104925  0.789741 -0.761621      0.163779
# 1457     0.651479     3.078570     0.215641  0.789741 -0.761621      1.390023
# 1458    -0.795151     0.381743     0.046905 -1.026041 -0.761621     -1.062465
# 1459    -0.795151     0.381743     0.452784 -1.026041  1.227585      0.163779
#
# ...

# %%
y = df['LotArea']
y
# Out:
# 0      -0.207142
# 1      -0.091886
# 2       0.073480
# 3      -0.096897
# 4       0.375148
#           ...
# 1455   -0.260560
# 1456    0.266407
# 1457   -0.147810
# 1458   -0.080160
# 1459   -0.058112
# Name: LotArea, Length: 1460, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42)

# %%
print('Training Features:', X_train)
print('Testing Features:', X_test)
print('Training Target:', y_train)
print('Testing Target:', y_test)
# Out:
# Training Features:       OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  BedroomAbvGr  \
# 135      0.651479     0.381743     0.562234  0.789741 -0.761621      0.163779
# 1452    -0.795151    -0.517200    -1.163889 -1.026041 -0.761621     -1.062465
# 762      0.651479    -0.517200    -0.687324  0.789741  1.227585      0.163779
# 932      2.098110    -0.517200     1.932643  0.789741 -0.761621      0.163779
# 435      0.651479     0.381743    -0.589275  0.789741  1.227585      0.163779
# ...           ...          ...          ...       ...       ...           ...
# 1095    -0.071836    -0.517200     0.585036  0.789741 -0.761621      0.163779
# 1130    -1.518467    -2.315085     0.147235  0.789741 -0.761621      1.390023
# 1294    -0.795151     1.280685    -0.441061 -1.026041 -0.761621     -1.062465
# 860      0.651479     2.179628    -0.331610 -1.026041  1.227585      0.163779
# 1126     0.651479    -0.517200     0.719569  0.789741 -0.761621     -1.062465
#
# ...
