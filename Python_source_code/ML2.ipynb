# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
data = pd.read_csv("Training_set_heights200.csv")

# %%
df=pd.DataFrame(data)
df
# Out:
#        Height    Weight
# 0    127.8296  67.63371
# 1    123.4114  65.95421
# 2    134.4043  66.14316
# 3    155.9981  73.45251
# 4    136.1354  69.30943
# ..        ...       ...
# 194  135.2500  68.41222
# 195  109.5143  66.49607
# 196  139.6043  67.84894
# 197  134.3672  67.27839
# 198  130.3869  68.48742
#
# [199 rows x 2 columns]

# %%
from sklearn import preprocessing
MM = preprocessing.MinMaxScaler()
x = MM.fit_transform(data)
print(x)
# Out:
# [[0.55738247 0.53872437]
#  [0.49548119 0.40985671]
#  [0.64949743 0.4243548 ]
#  [0.95203779 0.98519959]
#  [0.67375104 0.66730199]
#  [0.43738377 0.34466862]
#  [0.34908247 0.50992308]
#  [0.60113031 0.68675989]
#  [0.73623936 0.75590033]
#  [0.37092206 0.46972895]
#  [0.46437503 0.39039343]
#  [0.60406131 0.59593869]
#  [0.79874449 0.71333218]
#  [0.47575998 0.35674282]
#  [0.49263425 0.55948975]
#  [0.62913734 0.59716023]
#  [1.         0.60338839]
#  [0.54525776 0.3960699 ]
#  [0.64237588 0.57734553]
#  [0.73658121 0.8075786 ]
#  [0.54945671 0.68787861]
#  [0.75975041 0.65702327]
#  [0.55166617 0.80390401]
#  [0.73663586 0.72803437]
#  [0.34895497 0.56025398]
#  [0.64312404 0.59457137]
#  [0.57725078 0.4842585 ]
#  [0.41982578 0.39622106]
#  [0.60528863 0.44350885]
#  [0.60712822 0.32756095]
#  [0.81467165 0.79411713]
#  [0.38697672 0.18244576]
#  [0.46978589 0.62691681]
#  [0.76756548 0.43440256]
#  [0.48096068 0.57167827]
#  [0.39468531 0.6278859 ]
#  [0.51695651 0.31010646]
# ...

# %%
X = x[:,0]
Y = x[:,1]

# %%
X=X.reshape(1,-1)
Y=Y.reshape(1,-1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X,Y)
print(reg.intercept_)
print(reg.coef_)
# Out:
# [0.53872437 0.40985671 0.4243548  0.98519959 0.66730199 0.34466862
#  0.50992308 0.68675989 0.75590033 0.46972895 0.39039343 0.59593869
#  0.71333218 0.35674282 0.55948975 0.59716023 0.60338839 0.3960699
#  0.57734553 0.8075786  0.68787861 0.65702327 0.80390401 0.72803437
#  0.56025398 0.59457137 0.4842585  0.39622106 0.44350885 0.32756095
#  0.79411713 0.18244576 0.62691681 0.43440256 0.57167827 0.6278859
#  0.31010646 0.85938194 0.45115651 0.43224569 0.65371621 0.50407627
#  0.30173141 0.44000997 0.77748288 0.13784965 0.45147647 0.48554449
#  0.59573229 0.58968675 0.69297577 0.52247147 0.66102473 0.55225873
#  0.62757822 0.44235867 0.69027642 0.5681817  0.90035641 0.5202839
#  0.50415377 0.85937734 0.80953905 0.60002686 0.36238246 0.71725231
#  0.68251137 0.45112198 0.57993133 0.5218699  0.592825   0.54575358
#  0.54421362 0.54392818 0.2803261  0.72754868 0.40024016 0.49177879
#  0.52236021 0.60867814 0.         0.37853254 0.50281867 0.5088128
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x[:,0],x[:,1],test_size=0.30,
random_state=0)

# %%
def gd(xt,yt,m_b,n_b,L):
    D_m=0
    D_n=0
    for i in range(len(xt)):
        D_m =D_m +(2/len(xt))*((m_b*xt[i]+n_b-yt[i])*xt[i])
        D_n =D_n +(2/len(xt))*(m_b*xt[i]+n_b-yt[i])
    m_b = m_b - L * D_m
    n_b = n_b - L * D_n
    return m_b, n_b
m= 0
n= 0
L= 0.5
epochs = 900
for i in range(epochs):
    m, n =gd(X_train, y_train, m ,n , L)
    print(m, n)
# Out:
# 0.29400567314907805 0.5355308520634722
# 0.21307802410916096 0.37888432999762056
# 0.24027552379120423 0.4220026638218827
# 0.23621075007809111 0.4075118082936667
# 0.241105510028543 0.40967752386753253
# 0.24335463465579932 0.40706959078116406
# 0.2463078195764101 0.40587125488927905
# 0.24899945871098447 0.4042977949560878
# 0.2517091279093877 0.402863686884052
# 0.25435708546861596 0.4014199723756466
# 0.2569672571085028 0.40000913789144
# 0.2595336400543951 0.3986184357835392
# 0.26205885291274117 0.39725106433639273
# 0.2645430121874199 0.395905628353818
# 0.26698694223822983 0.3945820657624297
# 0.2693912492636815 0.3932799373424877
# 0.271756588732365 0.39199892011080817
# 0.27408358843631564 0.3907386648330589
# 0.27637287091243196 0.3894988370210041
# 0.27862504718730985 0.38827910498635015
# 0.2808407187933404 0.38707914317350456
# 0.2830204773946792 0.38589863108539685
# 0.2851649050995302 0.3847372534827622
# 0.2872745745710778 0.38359470021775693
# ...

# %%
def gd(xt,yt,m_b,n_b,L):
    D_m=0
    D_n=0
    for i in range(len(xt)):
        D_m =D_m +(2/len(xt))*((m_b*xt[i]+n_b-yt[i])*xt[i])
        D_n =D_n +(2/len(xt))*(m_b*xt[i]+n_b-yt[i])
    m_b = m_b - L * D_m
    n_b = n_b - L * D_n
    return m_b, n_b
m= 0
n= 0
L= 0.5
epochs = 900
for i in range(epochs):
    m, n =gd(X_train, y_train, m ,n , L)
    print(m, n)
# Out:
# 0.29400567314907805 0.5355308520634722
# 0.21307802410916096 0.37888432999762056
# 0.24027552379120423 0.4220026638218827
# 0.23621075007809111 0.4075118082936667
# 0.241105510028543 0.40967752386753253
# 0.24335463465579932 0.40706959078116406
# 0.2463078195764101 0.40587125488927905
# 0.24899945871098447 0.4042977949560878
# 0.2517091279093877 0.402863686884052
# 0.25435708546861596 0.4014199723756466
# 0.2569672571085028 0.40000913789144
# 0.2595336400543951 0.3986184357835392
# 0.26205885291274117 0.39725106433639273
# 0.2645430121874199 0.395905628353818
# 0.26698694223822983 0.3945820657624297
# 0.2693912492636815 0.3932799373424877
# 0.271756588732365 0.39199892011080817
# 0.27408358843631564 0.3907386648330589
# 0.27637287091243196 0.3894988370210041
# 0.27862504718730985 0.38827910498635015
# 0.2808407187933404 0.38707914317350456
# 0.2830204773946792 0.38589863108539685
# 0.2851649050995302 0.3847372534827622
# 0.2872745745710778 0.38359470021775693
# ...

# %%
plt.scatter(X_train,y_train)
y_pred = m*X_train+n
plt.plot(X_train,y_pred)

# %%
 from sklearn.metrics import mean_squared_error
y_test_pred = m * X_test + n
testing_error = mean_squared_error(y_test, y_test_pred)
print("Testing_Mean_Squared_Error:", testing_error)
# Out:
# Testing_Mean_Squared_Error: 0.027629530250748133

# %%
def gd(xt,yt,m_b,n_b,L):
    D_m=0
    D_n=0
    for i in range(len(xt)):
        D_m =D_m +(2/len(xt))*((m_b*xt[i]+n_b-yt[i])*xt[i])
        D_n =D_n +(2/len(xt))*(m_b*xt[i]+n_b-yt[i])
    m_b = m_b - L * D_m
    n_b = n_b - L * D_n
    return m_b, n_b
m= 0
n= 0
L= 0.7
epochs = 900
for i in range(epochs):
    m, n =gd(X_train, y_train, m ,n , L)
    print(m, n)
# Out:
# 0.41160794240870924 0.749743192888861
# 0.08834657332698803 0.14281873248424748
# 0.35572833693449823 0.626716097959496
# 0.14807753475425914 0.2337113654413306
# 0.32217526609460745 0.5458044408677712
# 0.18919421295509462 0.29110398271700216
# 0.30293840426694013 0.492177582732077
# 0.21816652054402091 0.32690391337261415
# 0.2928452296810868 0.456246545486006
# 0.2391815077326459 0.3488050434484057
# 0.28855727916265106 0.4318105642499578
# 0.25495040901703103 0.3617779101070564
# 0.2879213609460871 0.41485905625803216
# 0.2672303095515658 0.3690328583265826
# 0.2895502036608049 0.40279723605550666
# 0.27716134786939317 0.37264259772751773
# 0.2925514070777532 0.3939455660339803
# 0.28548468515180914 0.3739446038044104
# 0.29635225123905745 0.3872162079905751
# 0.2926834043519267 0.37380121592594157
# 0.30058646581036313 0.38190388425268007
# 0.2990735925711875 0.3727677540511651
# 0.3050210486916745 0.377550690695307
# 0.30486322266954746 0.3712011810887065
# ...

# %%
plt.scatter(X_train,y_train)
y_pred = m*X_train+n
plt.plot(X_train,y_pred)

# %%
from sklearn.metrics import mean_squared_error
y_test_pred = m * X_test + n
testing_error = mean_squared_error(y_test, y_test_pred)
print("Testing_Mean_Squared_Error:", testing_error)
# Out:
# Testing_Mean_Squared_Error: 0.02762952879023824

# %% [markdown]
# # Question 1: Linear Regression using Gradient Descent

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

data = pd.read_csv("Training_set_heights200.csv")

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

X = scaled_data[:, 1].reshape(-1, 1) 
y = scaled_data[:, 0] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=0)
def gradient_descent(X, y, m, n, learning_rate):

    N = len(X)

    y_pred = m * X + n

    dm = (-2/N) * sum(X * (y - y_pred))
    dn = (-2/N) * sum(y - y_pred)

    m_new = m - learning_rate * dm
    n_new = n - learning_rate * dn
    return m_new, n_new
def train_model(X, y, learning_rate=0.1, max_iterations=10000):
    m = 0
    n = 0
    m_history = [0, 0]
    n_history = [0, 0]
    for iteration in range(max_iterations):
# Get new parameters
        m_new, n_new = gradient_descent(X.flatten(), y, m, n, learning_rate)
# Update history
        m_history = [m_history[1], m_new]
        n_history = [n_history[1], n_new]
# Check convergence to 4 decimal places
        if (round(m_history[0], 4) == round(m_history[1], 4) and
            round(n_history[0], 4) == round(n_history[1], 4)):
            print(f"Converged after {iteration + 1} iterations")
            return m_new, n_new
        m, n = m_new, n_new
# Print progress every 1000 iterations
        if iteration % 1000 == 0:
            print(f"Iteration {iteration}: m = {m:.6f}, n = {n:.6f}")
    print("Maximum iterations reached")
    return m, n
# Train the model
learning_rate = 0.1
m, n = train_model(X_train, y_train, learning_rate=learning_rate)
# Make predictions
y_train_pred = m * X_train.flatten() + n
y_test_pred = m * X_test.flatten() + n
train_error = mean_squared_error(y_train, y_train_pred)
test_error = mean_squared_error(y_test, y_test_pred)
print("\nFinal Parameters:")
print(f"m (slope): {m:.6f}")
print(f"n (intercept): {n:.6f}")
print(f"\nTraining Mean Squared Error: {train_error:.6f}")
print(f"Testing Mean Squared Error: {test_error:.6f}")
# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Training Data')
plt.plot(X_train, y_train_pred, color='red', label='Regression Line')
plt.xlabel('Scaled Weight')
plt.ylabel('Scaled Height')
plt.title('Height vs Weight Linear Regression')
plt.legend()
plt.show()
# Inverse transform predictions to original scale for interpretation
# Create sample points for the line in original scale
X_line = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
y_line = m * X_line.flatten() + n
# Combine features and predictions for inverse transform
X_line_original = scaler.inverse_transform(np.column_stack([y_line, X_line.flatten()]))
data_original = scaler.inverse_transform(np.column_stack([y, X.flatten()]))
plt.figure(figsize=(10, 6))
plt.scatter(data_original[:, 1], data_original[:, 0], color='blue',label='Actual Data')
plt.plot(X_line_original[:, 1], X_line_original[:, 0], color='red',label='Regression Line')
plt.xlabel('Weight (original scale)')
plt.ylabel('Height (original scale)')
plt.title('Height vs Weight Linear Regression (Original Scale)')
plt.legend()
plt.show()
# Out:
# Iteration 0: m = 0.058801, n = 0.106560
# Converged after 693 iterations
#
# Final Parameters:
# m (slope): 0.425349
# n (intercept): 0.305251
#
# Training Mean Squared Error: 0.016956
# Testing Mean Squared Error: 0.021586
